# %%
import pandas as pd
datos = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning'
                 '-databases/autos/imports-85.data', encoding = 'utf-8',
                 )

# %%
datos
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
datos.isnull().sum()
# Out:
# 3              0
# ?              0
# alfa-romero    0
# gas            0
# std            0
# two            0
# convertible    0
# rwd            0
# front          0
# 88.60          0
# 168.80         0
# 64.10          0
# 48.80          0
# 2548           0
# dohc           0
# four           0
# 130            0
# mpfi           0
# 3.47           0
# 2.68           0
# 9.00           0
# 111            0
# 5000           0
# 21             0
# 27             0
# 13495          0
# dtype: int64

# %% [markdown]
# Se observa en la pagina web del dataset que las variables tienen datos perdidos:
# - price
# - peak-rmp
# - stroke
# - bore
# - num-of-doors
# - normalized-losses
# - horsepower

# %% [markdown]
# Se define los encabezados reales del dataset a fin de entender su informacion

# %%
column_headers = [
    "symboling", "normalized_losses", "make", "fuel_type", "aspiration", "num_of_doors",
    "body_style", "drive_wheels", "engine_location", "wheel_base", "length", "width",
    "height", "curb_weight", "engine_type", "num_of_cylinders", "engine_size", "fuel_system",
    "bore", "stroke", "compression_ratio", "horsepower", "peak_rpm", "city_mpg", "highway_mpg", "price"
]

datos.columns = column_headers

# %%
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# Se verifica los datos faltantes

# %%
datos.eq('?').sum()
# Out:
# symboling             0
# normalized_losses    40
# make                  0
# fuel_type             0
# aspiration            0
# num_of_doors          2
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Se puede reemplazar el ? por NaN

# %%
datos = datos.replace('?', pd.NA)
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3              <NA>  alfa-romero       gas        std
# 1            1              <NA>  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2              <NA>         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# - normalized-losses
# Es posible predecir los datos faltantes por ello usar bfill

# %%
datos.normalized_losses.fillna(method='bfill', inplace=True)
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # num-of-doors
# Se puede aplicar llenar por moda, debido a que es lo comun ver autos del mismo numero de puestas

# %%
moda = datos.num_of_doors.mode()
datos.num_of_doors.fillna(moda, inplace=True)
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # bore
# Se puede suponer la media

# %%
datos['bore'] = pd.to_numeric(datos['bore'], errors='coerce')  # 'coerce' convierte las cadenas no válidas a NaN

media = datos['bore'].mean()

print("La media de 'bore' es:", media)
datos.bore.fillna(media, inplace=True)
datos
# Out:
# La media de 'bore' es: 3.3290499999999996
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# ...

# %% [markdown]
# # stroke
# Es posible predecir los datos faltantes por ello usar bfill, pues se encuentra en orden

# %%
datos.stroke.fillna(method='bfill', inplace=True)
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # horsepower
# Es posible predecir los datos faltantes por ello usar bfill, pues se encuentra en orden

# %%
datos.horsepower.fillna(method='bfill', inplace=True)
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %% [markdown]
# # peak-rpm
# En mi opinion es un dato importante, por ello no lo reemplzaria, entonces se elimina

# %%
datos = datos.dropna(subset=['peak_rpm'])

# %% [markdown]
# # price
#
# En mi opinion es un dato importante, por ello no lo reemplzaria, entonces se elimina

# %%
datos = datos.dropna(subset=['price'])

# %%
datos.eq('?').sum()
# Out:
# symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %%
datos
# Out:
#      symboling normalized_losses         make fuel_type aspiration  \
# 0            3               164  alfa-romero       gas        std
# 1            1               164  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               158         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...
