# %% [markdown]
# Metodologia Utilizada KDD (Knowledge discovery in databases)

# %% [markdown]
# El primer paso de esta metodologia es Seleccion, en este paso vamos a seleccionar una base de datos para poder analizarla y al final de todos los 5 pasos sacar informacion util para la organizacion en la que estemos trabajando y asi ayudar a tomar desiciones en diferentes campos, tomando en cuenta todo el analisis que hemos hecho en el fondo.

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('mdi_personasdesaparecidas_pm_2023_enero_septiembre.csv', encoding='latin-1', sep=';')

# %%
df
# Out:
#                            Provincia      Latitud      Longitud  Edad Aprox.  \
# 0                   ZAMORA CHINCHIPE  -4,06805346  -78,95132173           16
# 1                          PICHINCHA  -0,21882160  -78,51354890           17
# 2                          PICHINCHA  -0,26909023  -78,54001523           17
# 3     SANTO DOMINGO DE LOS TSACHILAS   0,00916720  -79,39160500           39
# 4                          PICHINCHA  -0,17504166  -78,47478184           14
# ...                              ...          ...           ...          ...
# 5790  SANTO DOMINGO DE LOS TSACHILAS  -0,24776160  -79,14853740           14
# 5791                           AZUAY  -3,38988084  -79,08271046           15
# 5792                      CHIMBORAZO  -1,90845200  -78,64106800           22
# 5793                          GUAYAS  -2,07215490  -79,93451410           32
# 5794                       PICHINCHA  -0,30864288  -78,54081268           38
#
# ...

# %% [markdown]
# Etapa de pre-procesamiento/limpieza:
# En esta etapa se analiza la calidad de los datos y se buscan estrategias para reducir o eliminar los datos duplicados, datos nulos

# %%
df = df.replace('SIN_DATO', np.nan)
df
# Out:
#                            Provincia      Latitud      Longitud  Edad Aprox.  \
# 0                   ZAMORA CHINCHIPE  -4,06805346  -78,95132173           16
# 1                          PICHINCHA  -0,21882160  -78,51354890           17
# 2                          PICHINCHA  -0,26909023  -78,54001523           17
# 3     SANTO DOMINGO DE LOS TSACHILAS   0,00916720  -79,39160500           39
# 4                          PICHINCHA  -0,17504166  -78,47478184           14
# ...                              ...          ...           ...          ...
# 5790  SANTO DOMINGO DE LOS TSACHILAS  -0,24776160  -79,14853740           14
# 5791                           AZUAY  -3,38988084  -79,08271046           15
# 5792                      CHIMBORAZO  -1,90845200  -78,64106800           22
# 5793                          GUAYAS  -2,07215490  -79,93451410           32
# 5794                       PICHINCHA  -0,30864288  -78,54081268           38
#
# ...

# %%
df.isnull().sum()
# Out:
# Provincia                    0
# Latitud                      0
# Longitud                     0
# Edad Aprox.                  0
# Sexo                         0
# Motivo Desaparción         612
# Motivo Desaparción Obs.    612
# Fecha Desaparición           0
# Situación Actual             0
# Fecha Localización         612
# dtype: int64

# %%
duplicados = df.duplicated()
duplicados
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5790    False
# 5791    False
# 5792    False
# 5793    False
# 5794    False
# Length: 5795, dtype: bool

# %%
eliminarDup = df.drop_duplicates()

# %%
df.fillna(method='ffill', inplace=True)
df
# Out:
#                            Provincia      Latitud      Longitud  Edad Aprox.  \
# 0                   ZAMORA CHINCHIPE  -4,06805346  -78,95132173           16
# 1                          PICHINCHA  -0,21882160  -78,51354890           17
# 2                          PICHINCHA  -0,26909023  -78,54001523           17
# 3     SANTO DOMINGO DE LOS TSACHILAS   0,00916720  -79,39160500           39
# 4                          PICHINCHA  -0,17504166  -78,47478184           14
# ...                              ...          ...           ...          ...
# 5790  SANTO DOMINGO DE LOS TSACHILAS  -0,24776160  -79,14853740           14
# 5791                           AZUAY  -3,38988084  -79,08271046           15
# 5792                      CHIMBORAZO  -1,90845200  -78,64106800           22
# 5793                          GUAYAS  -2,07215490  -79,93451410           32
# 5794                       PICHINCHA  -0,30864288  -78,54081268           38
#
# ...

# %%
df.isnull().sum()
# Out:
# Provincia                  0
# Latitud                    0
# Longitud                   0
# Edad Aprox.                0
# Sexo                       0
# Motivo Desaparción         0
# Motivo Desaparción Obs.    0
# Fecha Desaparición         0
# Situación Actual           0
# Fecha Localización         0
# dtype: int64

# %% [markdown]
# Etapa de transformación/reducción
#
# En esta etapa se va a reducir o quitar datos que no vamos a utilizar o que no nos servira para nuestros intereses, esta reduccion se puede realizar en forma vertica u horizontal

# %%
df = df.drop(columns = ['Latitud', 'Longitud', 'Fecha Localización', 'Fecha Desaparición'])
df
# Out:
#                            Provincia  Edad Aprox.    Sexo  \
# 0                   ZAMORA CHINCHIPE           16   MUJER
# 1                          PICHINCHA           17  HOMBRE
# 2                          PICHINCHA           17   MUJER
# 3     SANTO DOMINGO DE LOS TSACHILAS           39  HOMBRE
# 4                          PICHINCHA           14   MUJER
# ...                              ...          ...     ...
# 5790  SANTO DOMINGO DE LOS TSACHILAS           14   MUJER
# 5791                           AZUAY           15   MUJER
# 5792                      CHIMBORAZO           22  HOMBRE
# 5793                          GUAYAS           32  HOMBRE
# 5794                       PICHINCHA           38  HOMBRE
#
#         Motivo Desaparción  Motivo Desaparción Obs. Situación Actual
# 0     PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES       ENCONTRADO
# 1     PROBLEMAS FAMILIARES  PROBLEMAS SENTIMENTALES     DESAPARECIDO
# ...

# %% [markdown]
# Etapa de minería de datos:
# En esta etapa se realizan la busqueda y descubrimiento de patrones de interes
